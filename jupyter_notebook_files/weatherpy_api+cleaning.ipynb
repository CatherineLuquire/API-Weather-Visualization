# %% [markdown]
# ## Import dependencies

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import pprint as pprint
import json
from pandas.io.json import json_normalize
from scipy.stats import linregress


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
# output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# base url
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# create queary url
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# create lists for city data  
city_list = []
lat = []
lon = []
max_temp = []
humidity = []
clouds = []
wind_speed = []
country = []
date = []


for city in cities:
    weather_json = requests.get(query_url + city).json()
    try:
        print(f'{str(cities.index(city)) + " " + weather_json["name"]}')
        city_list.append(weather_json["name"])
        lat.append(weather_json["coord"]["lat"])
        lon.append(weather_json["coord"]["lon"])
        max_temp.append(weather_json["main"]["temp_max"])
        humidity.append(weather_json['main']['humidity'])
        clouds.append(weather_json['clouds']['all'])
        wind_speed.append(weather_json['wind']['speed'])
        country.append(weather_json['sys']['country'])
        date.append(weather_json['dt'])
    except KeyError:
        print("City not found. Skipping...")
# Out:
# 0 Port Lincoln
# 1 Ushuaia
# 2 Cayenne
# 3 Treinta y Tres
# 4 Longyearbyen
# 5 Vao
# 6 Taltal
# 7 Punta Arenas
# 8 Ponta Delgada
# 9 Lorengau
# 10 Rikitea
# 11 Mataura
# 12 Touros
# 13 Haines Junction
# 14 Bluff
# 15 Yangi Marg`ilon
# 16 Esperance
# 17 Freeport
# 18 Bambous Virieux
# 19 Nikolskoye
# 20 Carnarvon
# 21 Nuuk
# 22 Port Alfred
# 23 Honolulu
# 24 Avarua
# 25 Tefé
# 26 Atuona
# 27 Nānākuli
# 28 Cap Malheureux
# 29 Busselton
# 30 Port Hardy
# 31 Hasaki
# 32 Bambanglipuro
# 33 Yellowknife
# 34 Butaritari
# 35 Netrakona
# 36 Thompson
# 37 Puerto Ayora
# 38 Vardø
# 39 Tafalla
# 40 Hong Kong
# 41 Oranjemund
# 42 Diffa
# 43 Port Elizabeth
# 44 Westport
# 45 Oussouye
# 46 Karpinsk
# 47 Chokurdakh
# 48 Balkhash
# 49 Lata
# 50 Lompoc
# 51 Bredasdorp
# 52 Sousa
# 53 Myaundzha
# 54 Verkhnetulomskiy
# 55 Kapaa
# 56 Lebu
# City not found. Skipping...
# 58 Safaga
# 59 Hithadhoo
# City not found. Skipping...
# 61 Kyshtovka
# 62 Cape Town
# 63 Esim
# 64 Kalianget
# 65 Narsaq
# 66 Ponta do Sol
# 67 San Cristobal
# 68 Hermanus
# 69 Normandin
# 70 East London
# 71 Shwebo
# 72 Tuktoyaktuk
# 73 Severodvinsk
# 74 Khor
# 75 Mt. Pleasant
# 76 Airai
# 77 Cabo San Lucas
# City not found. Skipping...
# 79 Qaanaaq
# 80 Hobart
# 81 Kaitangata
# City not found. Skipping...
# 83 Blagoyevo
# 84 Bereket
# 85 Vaini
# 86 Nemuro
# 87 Klaksvík
# 88 Bethel
# 89 Urusha
# 90 Wanning
# 91 Kuril'sk
# 92 Laguna
# 93 George Town
# 94 Coyhaique
# 95 Saint-Pierre
# 96 Imbituba
# 97 Buraidah
# 98 Tiksi
# 99 Castro
# 100 Mahébourg
# 101 Sibolga
# 102 Bengkulu
# 103 Norman Wells
# 104 Kumul
# 105 Saint-Philippe
# 106 Geraldton
# 107 Mar del Plata
# 108 Ayr
# 109 Fort Payne
# 110 Santa Maria
# 111 Faanui
# 112 Marzuq
# 113 Arraial do Cabo
# 114 Saint Anthony
# 115 Yumen
# 116 Hilo
# City not found. Skipping...
# 118 Khovd
# 119 Kudahuvadhoo
# 120 Marsh Harbour
# 121 Birao
# 122 Kapit
# 123 North Platte
# 124 Ugoofaaru
# 125 Camopi
# 126 Buchanan
# City not found. Skipping...
# 128 Morón
# 129 Torbay
# 130 Melfi
# 131 Kahului
# 132 New Norfolk
# 133 Örnsköldsvik
# 134 Redmond
# 135 Saskylakh
# 136 Kayerkan
# 137 Barrow
# City not found. Skipping...
# 139 Arroio Grande
# 140 Guerrero Negro
# 141 Albany
# City not found. Skipping...
# 143 Huarmey
# 144 Tiarei
# 145 Qarqīn
# 146 Ambunti
# 147 Tura
# 148 Mana
# City not found. Skipping...
# 150 Scarborough
# 151 Khatanga
# 152 Anloga
# City not found. Skipping...
# 154 Yulara
# 155 Tasiilaq
# 156 Hobyo
# City not found. Skipping...
# 158 Helong
# 159 Ribeira Grande
# 160 Bozeman
# 161 Mariakani
# 162 Lagos
# 163 Tuatapere
# 164 Marystown
# 165 Talnakh
# 166 Ancud
# 167 Dongsheng
# 168 Codrington
# 169 Loacan
# 170 Mayo
# 171 Dikson
# 172 Crestview
# 173 Jamestown
# 174 Shenjiamen
# 175 Forsytheganj
# 176 Mitsamiouli
# 177 Varna
# 178 Bar Harbor
# 179 Qasigiannguit
# 180 Urengoy
# 181 De Aar
# 182 Kununurra
# 183 Bernal
# 184 Kiryat Gat
# 185 Bathsheba
# City not found. Skipping...
# 187 Ahipara
# City not found. Skipping...
# 189 Kavieng
# 190 Clyde River
# 191 Upernavik
# 192 Doha
# 193 Te Anau
# 194 Bolu Province
# 195 Atar
# 196 Springville
# 197 Nova Viçosa
# 198 Iqaluit
# 199 Vila Velha
# 200 Caborca
# 201 Sangar
# 202 Pisco
# 203 Beyneu
# 204 Natal
# 205 Sanbu
# 206 Bonthe
# 207 Yanam
# 208 Cidreira
# 209 Dryden
# 210 Sasykoli
# 211 Chapais
# 212 Yendi
# 213 Bratsk
# 214 Liuzhou
# 215 Meulaboh
# 216 Lüderitz
# 217 Isangel
# 218 Dondo
# 219 Saint Paul Harbor
# 220 Nome
# 221 Tam Ky
# 222 Gibara
# 223 Antofagasta
# 224 Lichinga
# 225 Nouadhibou
# 226 Alto Araguaia
# 227 Qaqortoq
# 228 Road Town
# 229 Saint-François
# 230 Chabahar
# 231 Pevek
# City not found. Skipping...
# 233 Turochak
# 234 Boli
# 235 Ulaangom
# 236 Oktyabr'skiy
# City not found. Skipping...
# 238 Bon Air
# 239 Elbistan
# 240 Baykit
# 241 Belyy Yar
# 242 Almonte
# 243 Nantucket
# 244 Roald
# 245 North Vanlaiphai
# 246 Douglas
# 247 Prado
# 248 Olafsvik
# 249 Krasnokamensk
# 250 Teknāf
# 251 Rāyagada
# 252 Mount Isa
# 253 Kroya
# 254 Namatanai
# 255 Kataysk
# 256 Alofi
# 257 Sucúa
# 258 Samandağ
# 259 Provideniya
# 260 Beringovskiy
# 261 Gimli
# 262 Bacungan
# City not found. Skipping...
# City not found. Skipping...
# 265 Chul'man
# City not found. Skipping...
# 267 Honiara
# 268 Luwuk
# 269 Grand-Santi
# 270 Pauini
# 271 Sovetskoye
# 272 Apt
# 273 Zhuanghe
# 274 Papetoai
# 275 Teya
# 276 Araguaçu
# 277 Alyangula
# 278 Redlands
# 279 Stephenville
# 280 Mandera
# 281 Berndorf
# 282 Altay
# 283 Labuhan
# 284 Plácido de Castro
# 285 Cam Ranh
# 286 Coaldale
# 287 Banda Aceh
# 288 Fortuna
# City not found. Skipping...
# 290 Māngrol
# 291 Taft
# 292 Hofn
# 293 Maningrida
# City not found. Skipping...
# 295 Abu Dhabi
# 296 Broken Hill
# 297 Ende
# 298 Srednekolymsk
# 299 Mujiayingzi
# 300 Bac Lieu
# 301 Astoria
# 302 Benghazi
# 303 Firminy
# 304 Antalaha
# 305 George
# 306 Umm Hājar
# 307 Goffstown
# 308 Manavālakurichi
# 309 Prainha
# 310 Quatre Cocos
# 311 Kruisfontein
# 312 Arlit
# 313 Gokak
# 314 Sal Rei
# 315 Saldanha
# 316 Rio Grande
# 317 Kouroussa
# City not found. Skipping...
# 319 Challans
# 320 Camacha
# 321 Naples
# 322 Evensk
# 323 Sola
# 324 Sorong
# 325 Bolgatanga
# 326 Paamiut
# 327 Kastamonu Province
# 328 Lingao
# 329 Plettenberg Bay
# 330 Mutsu
# 331 Souillac
# 332 Tigil'
# 333 Barras
# 334 Russell
# 335 Hobbs
# 336 Iskateley
# 337 Maceió
# 338 Tatarka
# 339 Sinnamary
# City not found. Skipping...
# 341 El Jícaro
# 342 São Raimundo Nonato
# 343 Ocós
# 344 Guayabetal
# 345 Lagoa
# 346 Skibbereen
# 347 Warwick
# 348 Tsimmerbude
# 349 Viedma
# 350 Mafinga
# 351 Verkhoyansk
# 352 Taksimo
# 353 Beloomut
# 354 Hirara
# City not found. Skipping...
# 356 Manjeshwar
# 357 Camrose
# 358 Udachny
# 359 Pushkinskiye Gory
# 360 Bulgan
# 361 Hamilton
# 362 Salamiyah
# 363 Sitka
# 364 Wewak
# 365 Beyşehir
# 366 Bonavista
# 367 Carahue
# 368 Belfast
# 369 Cherskiy
# 370 Crateús
# 371 San Matías
# City not found. Skipping...
# 373 Tepechitlán
# 374 Santa Isabel Rio Negro
# 375 Raudeberg
# 376 High Rock
# 377 Katsuura
# 378 Sakakah
# 379 Laytown
# 380 Phichit
# 381 Lewistown
# 382 Kangaatsiaq
# 383 Acapulco de Juárez
# 384 Severo-Yeniseyskiy
# 385 Kloulklubed
# 386 Tateyama
# 387 Moerai
# 388 Mbanza-Ngungu
# 389 Illela
# 390 Yelan'
# 391 Āmlāgora
# 392 Curicó
# 393 Taraz
# 394 Kargil
# 395 Kismayo
# 396 Dingle
# 397 Presidencia Roque Sáenz Peña
# 398 Kimberley
# 399 Karoi
# 400 Estelle
# 401 Puri
# 402 Namtsy
# 403 Ankazoabo
# 404 Mahibadhoo
# 405 Neryungri
# 406 Buriti Alegre
# 407 Ylivieska
# 408 Adrar
# 409 Cachoeira do Sul
# 410 Sørland
# City not found. Skipping...
# 412 Sabang
# 413 Griffin
# 414 Dhrol
# 415 Leningradskiy
# City not found. Skipping...
# 417 Cullera
# 418 Pacific Grove
# 419 Los Llanos de Aridane
# 420 Mehamn
# 421 Kutum
# 422 Matamoros
# 423 Moen
# 424 Port Hedland
# 425 Brewster
# 426 Linhai
# 427 Chui
# 428 Bay Roberts
# City not found. Skipping...
# 430 Flinders
# 431 Severo-Kuril'sk
# 432 Coruripe
# 433 Kurchum
# 434 Santa Rosalía
# 435 Ilulissat
# 436 Tottori-shi
# 437 Deniliquin
# 438 Ziarat
# City not found. Skipping...
# 440 Izhma
# 441 Husavik
# 442 Pitimbu
# 443 Saint George
# 444 Cartagena del Chairá
# 445 Howard Springs
# 446 Key West
# 447 Ilanskiy
# 448 Coventry
# 449 Ucluelet
# 450 Sretensk
# 451 Shubarshi
# 452 Ledyard Center
# City not found. Skipping...
# 454 Ormara
# 455 Gamba
# 456 Balaipungut
# 457 Berdigestyakh
# 458 Iberia
# City not found. Skipping...
# 460 Marawi
# 461 Pokhara
# 462 Waddān
# 463 Pangnirtung
# City not found. Skipping...
# City not found. Skipping...
# 466 Dois Vizinhos
# 467 Naifaru
# 468 Rafai
# 469 Macapá
# 470 Liuli
# 471 Linjiang
# 472 Merauke
# 473 Nyrob
# 474 Abu Kamal
# 475 Ballina
# 476 Verkhnyaya Inta
# 477 The Pas
# 478 Dunedin
# 479 Palmer
# 480 Orange Cove
# 481 Chunoyar
# 482 Maniitsoq
# 483 Yakeshi
# 484 Yar-Sale
# 485 Slonim
# 486 Faya
# 487 Dalbandin
# 488 Lemgo
# 489 Sobolevo
# 490 Byron Bay
# 491 Dicabisagan
# 492 Samarai
# 493 Lavrentiya
# City not found. Skipping...
# 495 Cuicatlan
# City not found. Skipping...
# City not found. Skipping...
# 498 Broome
# 499 Ranau
# 500 Kabinda
# 501 Bunia
# 502 Koslan
# 503 North Las Vegas
# 504 Vila Franca do Campo
# 505 ‘Ewa Beach
# City not found. Skipping...
# 507 Ginda
# 508 Gainesville
# 509 Rolla
# 510 Avera
# 511 Ceres
# 512 Olinda
# 513 Richards Bay
# 514 Linqing
# 515 Tafresh
# 516 Aklavik
# 517 Shatrovo
# 518 Flin Flon
# 519 Lázaro Cárdenas
# City not found. Skipping...
# 521 Dzerzhinskoye
# 522 Gurupi
# 523 Mossamedes
# 524 Grand Forks
# 525 Valdosta
# 526 Cururupu
# 527 Ilām
# 528 Lavras da Mangabeira
# 529 Mount Gambier
# 530 Rocha
# 531 Wawa
# 532 Ardeşen
# 533 Bāglung
# 534 Putina
# 535 Dakar
# 536 Maragogi
# 537 Shache
# 538 Fort Nelson
# 539 Usinsk
# 540 Karasburg
# 541 São João da Barra
# 542 Mulegé
# 543 Bara
# 544 Luau
# 545 City of San Pedro
# 546 Puro
# City not found. Skipping...
# 548 Robe
# City not found. Skipping...
# 550 Charleston
# 551 Shakawe
# 552 Gambēla
# 553 Omboué
# 554 Plainview
# 555 Hohhot
# 556 Ulfborg
# 557 Divnomorskoye
# 558 San Patricio
# 559 Eura
# 560 Zhigansk
# 561 Ukiah
# 562 Puerto El Triunfo
# 563 Ushtobe
# 564 Ngunguru
# 565 Lora del Río
# 566 Grindavik
# 567 Chute-aux-Outardes
# 568 Rodrigues Alves
# 569 Meadow Lake
# 570 Sistranda
# 571 Zelenoborskiy
# 572 Anadyr
# 573 Havelock
# 574 Arica
# 575 Xi'an
# 576 Aasiaat
# 577 Nakhon Thai
# 578 Puerto Escondido
# 579 Fare
# 580 Leopoldsburg
# 581 Padang
# 582 Aki
# 583 Ulladulla
# 584 Port Augusta
# 585 Cortez
# 586 Lucea
# 587 Shimoda
# 588 Thinadhoo
# 589 Cabedelo
# 590 Zhangjiakou Shi Xuanhua Qu
# City not found. Skipping...
# 592 Emmett
# City not found. Skipping...
# 594 Augusto Corrêa
# 595 Half Moon Bay
# 596 Krabi
# 597 Livingston
# 598 ‘Āhuimanu
# 599 Nokaneng
# City not found. Skipping...
# 601 Fairbanks
# 602 Hay River
# 603 Gīdam
# 604 Muros
# 605 Bom Jesus
# 606 Karratha
# 607 Praia da Vitória
# 608 Amapá
# 609 Pavlovka
# 610 Margate
# 611 Mil'kovo
# 612 Jieshi
# 613 Gao
# 614 Ponnāni
# 615 La Ronge
# 616 Taoudenni
# 617 Huilong
# 618 Corinth
# 619 Cockburn Town

# %%
# create weather dictionary and convert it to a dataframe 

weather_dict = {
    "City": city_list,
    "Latitude": lat,
    "Longitude": lon,
    "Max Temp": max_temp,
    "Humidity": humidity,
    "Cloudiness": clouds,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date}

weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#              City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0    Port Lincoln    -34.73     135.87     15.71        62          25
# 1         Ushuaia    -54.80     -68.30      2.00        80          40
# 2         Cayenne      4.93     -52.33     26.00        88          26
# 3  Treinta y Tres    -33.23     -54.38      2.34        84           0
# 4    Longyearbyen     78.22      15.64     11.00        81          75
#
#    Wind Speed Country        Date
# 0        4.56      AU  1595989716
# 1        9.30      AR  1595989716
# 2        5.59      GF  1595989716
# 3        2.63      UY  1595989717
# 4        5.10      SJ  1595989645

# %%
# convert to fahrenheit and mph & rename column titles 
temp = ((weather_df["Max Temp"] * 9/5) + 32)
weather_df["Max Temp"] = temp
wind = (weather_df["Wind Speed"] * 2.23694)
weather_df["Wind Speed"] = wind
weather_data = weather_df.rename(columns={"Max Temp": "Max Temp (F)",
                            "Wind Speed": "Wind Speed (mph)",
                            "Humidity": "Humidity %", 
                            "Cloudiness": "Cloudiness %"})
                   
weather_data.head()
# Out:
#              City  Latitude  Longitude  Max Temp (F)  Humidity %  \
# 0    Port Lincoln    -34.73     135.87        60.278          62
# 1         Ushuaia    -54.80     -68.30        35.600          80
# 2         Cayenne      4.93     -52.33        78.800          88
# 3  Treinta y Tres    -33.23     -54.38        36.212          84
# 4    Longyearbyen     78.22      15.64        51.800          81
#
#    Cloudiness %  Wind Speed (mph) Country        Date
# 0            25         10.200446      AU  1595989716
# 1            40         20.803542      AR  1595989716
# 2            26         12.504495      GF  1595989716
# 3             0          5.883152      UY  1595989717
# 4            75         11.408394      SJ  1595989645

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data.to_csv("output_data/weatherdata.csv", index=False, header=True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
high_hum = weather_data.loc[weather_data["Humidity %"] >= 100]
high_hum
# Out:
#                    City  Latitude  Longitude  Max Temp (F)  Humidity %  \
# 21                 Nuuk     64.18     -51.72        44.600         100
# 45             Oussouye     12.48     -16.55        75.200         100
# 54     Verkhnetulomskiy     68.61      31.80        53.600         100
# 89          George Town      5.41     100.34        82.400         100
# 127        Örnsköldsvik     63.29      18.72        55.400         100
# 155               Ancud    -41.87     -73.82        37.994         100
# 161           Crestview     30.76     -86.57        77.000         100
# 177         Clyde River     70.47     -68.59        37.400         100
# 205               Dondo    -19.61      34.74        59.000         100
# 230    North Vanlaiphai     23.13      93.07        68.558         100
# 270             Fortuna     40.60    -124.16        57.992         100
# 376             Estelle     29.85     -90.11        78.008         100
# 429              Iberia     29.95     -91.75        75.200         100
# 527           Grindavik     63.84     -22.43        50.000         100
# 528  Chute-aux-Outardes     49.12     -68.40        59.000         100
# 555               Krabi      8.07      98.91        80.600         100
#
#      Cloudiness %  Wind Speed (mph) Country        Date
# 21            100          1.118470      GL  1595989416
# 45             40          2.236940      SN  1595989721
# 54              0          2.393526      RU  1595989722
# 89             20          5.816044      MY  1595989566
# 127            98          2.236940      SE  1595989697
# 155            90          3.355410      CL  1595989734
# 161            90          6.845036      US  1595989734
# 177            90         11.408394      CA  1595989737
# 205            20          4.697574      MZ  1595989740
# 230           100          0.648713      IN  1595989743
# 270            90          9.171454      US  1595989749
# 376            90          3.355410      US  1595989763
# 429             1          4.697574      US  1595989771
# 527            90          4.697574      IS  1595989785
# 528            90         13.869028      CA  1595989785
# 555            75          2.236940      TH  1595989788

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_data.drop(index=high_hum.index)
clean_city_data.head(25)
# Out:
#                City  Latitude  Longitude  Max Temp (F)  Humidity %  \
# 0      Port Lincoln    -34.73     135.87        60.278          62
# 1           Ushuaia    -54.80     -68.30        35.600          80
# 2           Cayenne      4.93     -52.33        78.800          88
# 3    Treinta y Tres    -33.23     -54.38        36.212          84
# 4      Longyearbyen     78.22      15.64        51.800          81
# 5               Vao    -22.67     167.48        71.402          79
# 6            Taltal    -25.40     -70.48        59.144          61
# 7      Punta Arenas    -53.15     -70.92        39.200          81
# 8     Ponta Delgada     37.73     -25.67        71.600          94
# 9          Lorengau     -2.02     147.27        85.982          63
# 10          Rikitea    -23.12    -134.97        72.518          81
# 11          Mataura    -46.19     168.86        50.954          65
# 12           Touros     -5.20     -35.46        69.800          94
# 13  Haines Junction     60.75    -137.51        52.070          86
# 14            Bluff    -46.60     168.33        49.226          70
# 15  Yangi Marg`ilon     40.43      71.72        78.800          41
# 16        Esperance    -33.87     121.90        55.400          87
# 17         Freeport     40.66     -73.58        84.200          54
# 18  Bambous Virieux    -20.34      57.76        68.000          88
# 19       Nikolskoye     59.70      30.79        62.006          93
# 20        Carnarvon    -24.87     113.63        69.800          52
# 22      Port Alfred    -33.59      26.89        57.740          80
# 23         Honolulu     21.31    -157.86        84.200          51
# 24           Avarua    -21.21    -159.78        73.400          78
# 25             Tefé     -3.35     -64.71        74.696          88
#
#     Cloudiness %  Wind Speed (mph) Country        Date
# 0             25         10.200446      AU  1595989716
# 1             40         20.803542      AR  1595989716
# 2             26         12.504495      GF  1595989716
# 3              0          5.883152      UY  1595989717
# 4             75         11.408394      SJ  1595989645
# 5            100         29.080220      NC  1595989717
# 6             18          3.355410      CL  1595989717
# 7             75         16.105968      CL  1595989717
# 8             20          6.934514      PT  1595989717
# 9             30          8.992499      PG  1595989717
# 10             1         13.779550      PF  1595989717
# 11           100          5.816044      NZ  1595989717
# 12            20          4.697574      BR  1595989718
# 13           100          0.492127      CA  1595989718
# 14           100          6.308171      NZ  1595989718
# 15           100          6.934514      UZ  1595989718
# 16             3          6.934514      AU  1595989718
# 17             1          5.816044      US  1595989574
# 18            20          6.934514      MU  1595989718
# 19            40          2.236940      RU  1595989718
# 20             0         14.987498      AU  1595989718
# 22             0         12.840036      ZA  1595989718
# 23            75         17.224438      US  1595989616
# 24            73         10.289924      CK  1595989719
# 25             8          1.342164      BR  1595989719

# %%
# Extract relevant fields from the data frame

# Export the City_Data into a csv
clean_city_data.to_csv("output_data/cleancitydata.csv", index=False, header=True)
